# %% [markdown]
# Download stocks data from Yahoo Finance.
# Note that by updating the list of stocks, some of the results from the notebook will change and conclusions will be different.

# %%
import pandas as pd
import yfinance
import time

# choose which stocks to download
stocks = ['META', 'GOOGL', 'TSLA', 'MSFT', 'AAPL', 'AMZN']

# the dataframe data will hold the all data
df = pd.DataFrame()
for stock in stocks:
    # download stocks individuly
    df_temp = yfinance.download(stock, start='1990-01-01')

    # choose which columns/features to maintain and append the name of the stock to it
    df_temp.columns = ["_".join(tp) for tp in df_temp.columns]

    # merge to  the complete dataframe
    df = df.merge(df_temp, left_index=True, right_index=True, how='outer')

# show some info (different stocks have different number of recrods)
df.info()

# save the dataframe in the 'data' folder
filename = '_stocks.csv'
print()
print('saving file to', filename, end='... ')
df.to_csv(filename)
print('done')

now = time.strftime("%a, %d %b %Y %H:%M:%S %Z", time.localtime(time.time()))
print('updated:', now)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.DataFrame'>
# DatetimeIndex: 9137 entries, 1990-01-02 to 2026-04-14
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Close_META    3495 non-null   float64
#  1   High_META     3495 non-null   float64
#  2   Low_META      3495 non-null   float64
#  3   Open_META     3495 non-null   float64
#  4   Volume_META   3495 non-null   float64
#  5   Close_GOOGL   5447 non-null   float64
#  6   High_GOOGL    5447 non-null   float64
#  7   Low_GOOGL     5447 non-null   float64
#  8   Open_GOOGL    5447 non-null   float64
#  9   Volume_GOOGL  5447 non-null   float64
#  10  Close_TSLA    3972 non-null   float64
#  11  High_TSLA     3972 non-null   float64
#  12  Low_TSLA      3972 non-null   float64
#  13  Open_TSLA     3972 non-null   float64
#  14  Volume_TSLA   3972 non-null   float64
#  15  Close_MSFT    9137 non-null   float64
#  16  High_MSFT     9137 non-null   float64
#  17  Low_MSFT      9137 non-null   float64
#  18  Open_MSFT     9137 non-null   float64
#  19  Volume_MSFT   9137 non-null   int64
#  20  Close_AAPL    9137 non-null   float64
#  21  High_AAPL     9137 non-null   float64
#  22  Low_AAPL      9137 non-null   float64
#  23  Open_AAPL     9137 non-null   float64
#  24  Volume_AAPL   9137 non-null   int64
#  25  Close_AMZN    7273 non-null   float64
#  26  High_AMZN     7273 non-null   float64
#  27  Low_AMZN      7273 non-null   float64
#  28  Open_AMZN     7273 non-null   float64
#  29  Volume_AMZN   7273 non-null   float64
# dtypes: float64(28), int64(2)
# memory usage: 2.2 MB
#
# saving file to _stocks.csv... done
# updated: Tue, 14 Apr 2026 18:47:22 GMT Daylight Time

# %%
df_temp
# Out:
#             Close_AMZN   High_AMZN    Low_AMZN   Open_AMZN  Volume_AMZN
# Date
# 1997-05-15    0.097917    0.125000    0.096354    0.121875   1443120000
# 1997-05-16    0.086458    0.098958    0.085417    0.098438    294000000
# 1997-05-19    0.085417    0.088542    0.081250    0.088021    122136000
# 1997-05-20    0.081771    0.087500    0.081771    0.086458    109344000
# 1997-05-21    0.071354    0.082292    0.068750    0.081771    377064000
# ...                ...         ...         ...         ...          ...
# 2026-04-08  221.250000  226.100006  219.619995  223.789993     51092700
# 2026-04-09  233.649994  233.800003  223.270004  225.229996     65964200
# 2026-04-10  238.380005  240.429993  235.210007  235.300003     56912800
# 2026-04-13  239.889999  240.000000  235.750000  237.449997     42075000
# 2026-04-14  251.789993  252.179993  241.779999  241.779999     43727973
#
# [7273 rows x 5 columns]

# %% [markdown]
# _____
#
# <table align="left" width=100%>
#     <td>
#         <div style="text-align: center;">
#           <img src="./images/bar.png" alt="entidades financiadoras"/>
#         </div>
#     </td>
#     <td>
#         <p style="text-align: center; font-size:24px;"><b>Introduction to Data Science</b></p>
#         <p style="text-align: center; font-size:18px;"><b>Master in Electrical and Computer Engineering</b></p>
#         <p style="text-align: center; font-size:14px;"><b>Pedro Cardoso (pcardoso@ualg.pt)</b></p>
#     </td>
# </table>
#
# _____

# %% [markdown]
# # Weather Data Exercise
# Consider the data inserted into the weatherdb database by the following code.

# %%
import pymongo

# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client.weatherdb
weather = db.weather

# Sample data - list of 10 documents with weather information
weather_data = [
    # New York (Base: temp=20, humidity=60, wind_speed=5)
    {"date": "2024-02-26", "temperature": 20, "humidity": 60, "wind_speed": 5, "location": "New York"},
    {"date": "2024-02-27", "temperature": 21, "humidity": 59, "wind_speed": 5, "location": "New York"},
    {"date": "2024-02-28", "temperature": 20, "humidity": 61, "wind_speed": 6, "location": "New York"},
    {"date": "2024-02-29", "temperature": 22, "humidity": 60, "wind_speed": 5, "location": "New York"},
    {"date": "2024-03-01", "temperature": 21, "humidity": 62, "wind_speed": 4, "location": "New York"},
    {"date": "2024-03-02", "temperature": 20, "humidity": 60, "wind_speed": 5, "location": "New York"},
    {"date": "2024-03-03", "temperature": 19, "humidity": 63, "wind_speed": 6, "location": "New York"},
    {"date": "2024-03-04", "temperature": 20, "humidity": 60, "wind_speed": 5, "location": "New York"},
    {"date": "2024-03-05", "temperature": 21, "humidity": 59, "wind_speed": 5, "location": "New York"},
    {"date": "2024-03-06", "temperature": 20, "humidity": 61, "wind_speed": 6, "location": "New York"},

    # Los Angeles (Base: temp=25, humidity=55, wind_speed=7)
    {"date": "2024-02-26", "temperature": 25, "humidity": 55, "wind_speed": 7, "location": "Los Angeles"},
    {"date": "2024-02-27", "temperature": 26, "humidity": 54, "wind_speed": 7, "location": "Los Angeles"},
    {"date": "2024-02-28", "temperature": 25, "humidity": 56, "wind_speed": 8, "location": "Los Angeles"},
    {"date": "2024-02-29", "temperature": 27, "humidity": 55, "wind_speed": 7, "location": "Los Angeles"},
    {"date": "2024-03-01", "temperature": 26, "humidity": 57, "wind_speed": 6, "location": "Los Angeles"},
    {"date": "2024-03-02", "temperature": 25, "humidity": 55, "wind_speed": 7, "location": "Los Angeles"},
    {"date": "2024-03-03", "temperature": 24, "humidity": 58, "wind_speed": 6, "location": "Los Angeles"},
    {"date": "2024-03-04", "temperature": 25, "humidity": 55, "wind_speed": 7, "location": "Los Angeles"},
    {"date": "2024-03-05", "temperature": 26, "humidity": 54, "wind_speed": 8, "location": "Los Angeles"},
    {"date": "2024-03-06", "temperature": 25, "humidity": 56, "wind_speed": 7, "location": "Los Angeles"},

    # Chicago (Base: temp=18, humidity=70, wind_speed=4)
    {"date": "2024-02-26", "temperature": 18, "humidity": 70, "wind_speed": 4, "location": "Chicago"},
    {"date": "2024-02-27", "temperature": 17, "humidity": 71, "wind_speed": 4, "location": "Chicago"},
    {"date": "2024-02-28", "temperature": 18, "humidity": 70, "wind_speed": 5, "location": "Chicago"},
    {"date": "2024-02-29", "temperature": 16, "humidity": 72, "wind_speed": 4, "location": "Chicago"},
    {"date": "2024-03-01", "temperature": 17, "humidity": 73, "wind_speed": 5, "location": "Chicago"},
    {"date": "2024-03-02", "temperature": 18, "humidity": 70, "wind_speed": 4, "location": "Chicago"},
    {"date": "2024-03-03", "temperature": 19, "humidity": 69, "wind_speed": 4, "location": "Chicago"},
    {"date": "2024-03-04", "temperature": 18, "humidity": 70, "wind_speed": 5, "location": "Chicago"},
    {"date": "2024-03-05", "temperature": 17, "humidity": 71, "wind_speed": 4, "location": "Chicago"},
    {"date": "2024-03-06", "temperature": 18, "humidity": 70, "wind_speed": 4, "location": "Chicago"},

    # Houston (Base: temp=22, humidity=50, wind_speed=6)
    {"date": "2024-02-26", "temperature": 22, "humidity": 50, "wind_speed": 6, "location": "Houston"},
    {"date": "2024-02-27", "temperature": 23, "humidity": 49, "wind_speed": 6, "location": "Houston"},
    {"date": "2024-02-28", "temperature": 22, "humidity": 51, "wind_speed": 7, "location": "Houston"},
    {"date": "2024-02-29", "temperature": 24, "humidity": 50, "wind_speed": 6, "location": "Houston"},
    {"date": "2024-03-01", "temperature": 23, "humidity": 52, "wind_speed": 5, "location": "Houston"},
    {"date": "2024-03-02", "temperature": 22, "humidity": 50, "wind_speed": 6, "location": "Houston"},
    {"date": "2024-03-03", "temperature": 21, "humidity": 53, "wind_speed": 6, "location": "Houston"},
    {"date": "2024-03-04", "temperature": 22, "humidity": 50, "wind_speed": 7, "location": "Houston"},
    {"date": "2024-03-05", "temperature": 23, "humidity": 49, "wind_speed": 6, "location": "Houston"},
    {"date": "2024-03-06", "temperature": 22, "humidity": 51, "wind_speed": 6, "location": "Houston"},

    # Miami (Base: temp=23, humidity=45, wind_speed=8)
    {"date": "2024-02-26", "temperature": 23, "humidity": 45, "wind_speed": 8, "location": "Miami"},
    {"date": "2024-02-27", "temperature": 24, "humidity": 44, "wind_speed": 8, "location": "Miami"},
    {"date": "2024-02-28", "temperature": 23, "humidity": 46, "wind_speed": 9, "location": "Miami"},
    {"date": "2024-02-29", "temperature": 25, "humidity": 45, "wind_speed": 8, "location": "Miami"},
    {"date": "2024-03-01", "temperature": 24, "humidity": 47, "wind_speed": 7, "location": "Miami"},
    {"date": "2024-03-02", "temperature": 23, "humidity": 45, "wind_speed": 8, "location": "Miami"},
    {"date": "2024-03-03", "temperature": 22, "humidity": 48, "wind_speed": 8, "location": "Miami"},
    {"date": "2024-03-04", "temperature": 23, "humidity": 45, "wind_speed": 9, "location": "Miami"},
    {"date": "2024-03-05", "temperature": 24, "humidity": 44, "wind_speed": 8, "location": "Miami"},
    {"date": "2024-03-06", "temperature": 23, "humidity": 46, "wind_speed": 8, "location": "Miami"},

    # San Francisco (Base: temp=19, humidity=65, wind_speed=3)
    {"date": "2024-02-26", "temperature": 19, "humidity": 65, "wind_speed": 3, "location": "San Francisco"},
    {"date": "2024-02-27", "temperature": 20, "humidity": 64, "wind_speed": 3, "location": "San Francisco"},
    {"date": "2024-02-28", "temperature": 19, "humidity": 66, "wind_speed": 4, "location": "San Francisco"},
    {"date": "2024-02-29", "temperature": 18, "humidity": 65, "wind_speed": 3, "location": "San Francisco"},
    {"date": "2024-03-01", "temperature": 19, "humidity": 67, "wind_speed": 2, "location": "San Francisco"},
    {"date": "2024-03-02", "temperature": 20, "humidity": 65, "wind_speed": 3, "location": "San Francisco"},
    {"date": "2024-03-03", "temperature": 21, "humidity": 64, "wind_speed": 3, "location": "San Francisco"},
    {"date": "2024-03-04", "temperature": 19, "humidity": 65, "wind_speed": 4, "location": "San Francisco"},
    {"date": "2024-03-05", "temperature": 20, "humidity": 64, "wind_speed": 3, "location": "San Francisco"},
    {"date": "2024-03-06", "temperature": 19, "humidity": 66, "wind_speed": 3, "location": "San Francisco"},

    # Seattle (Base: temp=21, humidity=58, wind_speed=6)
    {"date": "2024-02-26", "temperature": 21, "humidity": 58, "wind_speed": 6, "location": "Seattle"},
    {"date": "2024-02-27", "temperature": 22, "humidity": 57, "wind_speed": 6, "location": "Seattle"},
    {"date": "2024-02-28", "temperature": 21, "humidity": 59, "wind_speed": 7, "location": "Seattle"},
    {"date": "2024-02-29", "temperature": 23, "humidity": 58, "wind_speed": 6, "location": "Seattle"},
    {"date": "2024-03-01", "temperature": 22, "humidity": 60, "wind_speed": 5, "location": "Seattle"},
    {"date": "2024-03-02", "temperature": 21, "humidity": 58, "wind_speed": 6, "location": "Seattle"},
    {"date": "2024-03-03", "temperature": 20, "humidity": 61, "wind_speed": 7, "location": "Seattle"},
    {"date": "2024-03-04", "temperature": 21, "humidity": 58, "wind_speed": 6, "location": "Seattle"},
    {"date": "2024-03-05", "temperature": 22, "humidity": 57, "wind_speed": 6, "location": "Seattle"},
    {"date": "2024-03-06", "temperature": 21, "humidity": 59, "wind_speed": 7, "location": "Seattle"},

    # Dallas (Base: temp=24, humidity=52, wind_speed=7)
    {"date": "2024-02-26", "temperature": 24, "humidity": 52, "wind_speed": 7, "location": "Dallas"},
    {"date": "2024-02-27", "temperature": 25, "humidity": 51, "wind_speed": 7, "location": "Dallas"},
    {"date": "2024-02-28", "temperature": 24, "humidity": 53, "wind_speed": 8, "location": "Dallas"},
    {"date": "2024-02-29", "temperature": 26, "humidity": 52, "wind_speed": 7, "location": "Dallas"},
    {"date": "2024-03-01", "temperature": 25, "humidity": 54, "wind_speed": 6, "location": "Dallas"},
    {"date": "2024-03-02", "temperature": 24, "humidity": 52, "wind_speed": 7, "location": "Dallas"},
    {"date": "2024-03-03", "temperature": 23, "humidity": 55, "wind_speed": 7, "location": "Dallas"},
    {"date": "2024-03-04", "temperature": 24, "humidity": 52, "wind_speed": 8, "location": "Dallas"},
    {"date": "2024-03-05", "temperature": 25, "humidity": 51, "wind_speed": 7, "location": "Dallas"},
    {"date": "2024-03-06", "temperature": 24, "humidity": 53, "wind_speed": 7, "location": "Dallas"},

    # Boston (Base: temp=17, humidity=68, wind_speed=4)
    {"date": "2024-02-26", "temperature": 17, "humidity": 68, "wind_speed": 4, "location": "Boston"},
    {"date": "2024-02-27", "temperature": 16, "humidity": 69, "wind_speed": 4, "location": "Boston"},
    {"date": "2024-02-28", "temperature": 17, "humidity": 68, "wind_speed": 5, "location": "Boston"},
    {"date": "2024-02-29", "temperature": 15, "humidity": 70, "wind_speed": 4, "location": "Boston"},
    {"date": "2024-03-01", "temperature": 16, "humidity": 71, "wind_speed": 5, "location": "Boston"},
    {"date": "2024-03-02", "temperature": 17, "humidity": 68, "wind_speed": 4, "location": "Boston"},
    {"date": "2024-03-03", "temperature": 18, "humidity": 67, "wind_speed": 4, "location": "Boston"},
    {"date": "2024-03-04", "temperature": 17, "humidity": 68, "wind_speed": 5, "location": "Boston"},
    {"date": "2024-03-05", "temperature": 16, "humidity": 69, "wind_speed": 4, "location": "Boston"},
    {"date": "2024-03-06", "temperature": 17, "humidity": 68, "wind_speed": 4, "location": "Boston"},

    # Phoenix (Base: temp=20, humidity=62, wind_speed=5)
    {"date": "2024-02-26", "temperature": 20, "humidity": 62, "wind_speed": 5, "location": "Phoenix"},
    {"date": "2024-02-27", "temperature": 21, "humidity": 61, "wind_speed": 5, "location": "Phoenix"},
    {"date": "2024-02-28", "temperature": 20, "humidity": 63, "wind_speed": 6, "location": "Phoenix"},
    {"date": "2024-02-29", "temperature": 22, "humidity": 62, "wind_speed": 5, "location": "Phoenix"},
    {"date": "2024-03-01", "temperature": 21, "humidity": 64, "wind_speed": 4, "location": "Phoenix"},
    {"date": "2024-03-02", "temperature": 20, "humidity": 62, "wind_speed": 5, "location": "Phoenix"},
    {"date": "2024-03-03", "temperature": 19, "humidity": 65, "wind_speed": 5, "location": "Phoenix"},
    {"date": "2024-03-04", "temperature": 20, "humidity": 62, "wind_speed": 6, "location": "Phoenix"},
    {"date": "2024-03-05", "temperature": 21, "humidity": 61, "wind_speed": 5, "location": "Phoenix"},
    {"date": "2024-03-06", "temperature": 20, "humidity": 63, "wind_speed": 5, "location": "Phoenix"}
]

# Insert the weather data into the collection
weather.insert_many(weather_data)
# Out:
# InsertManyResult([ObjectId('67be3b4e52d92383db2b2203'), ObjectId('67be3b4e52d92383db2b2204'), ObjectId('67be3b4e52d92383db2b2205'), ObjectId('67be3b4e52d92383db2b2206'), ObjectId('67be3b4e52d92383db2b2207'), ObjectId('67be3b4e52d92383db2b2208'), ObjectId('67be3b4e52d92383db2b2209'), ObjectId('67be3b4e52d92383db2b220a'), ObjectId('67be3b4e52d92383db2b220b'), ObjectId('67be3b4e52d92383db2b220c'), ObjectId('67be3b4e52d92383db2b220d'), ObjectId('67be3b4e52d92383db2b220e'), ObjectId('67be3b4e52d92383db2b220f'), ObjectId('67be3b4e52d92383db2b2210'), ObjectId('67be3b4e52d92383db2b2211'), ObjectId('67be3b4e52d92383db2b2212'), ObjectId('67be3b4e52d92383db2b2213'), ObjectId('67be3b4e52d92383db2b2214'), ObjectId('67be3b4e52d92383db2b2215'), ObjectId('67be3b4e52d92383db2b2216'), ObjectId('67be3b4e52d92383db2b2217'), ObjectId('67be3b4e52d92383db2b2218'), ObjectId('67be3b4e52d92383db2b2219'), ObjectId('67be3b4e52d92383db2b221a'), ObjectId('67be3b4e52d92383db2b221b'), ObjectId('67be3b4e52d92383db2b221c'), ObjectId('67be3b4e52d92383db2b221d'), ObjectId('67be3b4e52d92383db2b221e'), ObjectId('67be3b4e52d92383db2b221f'), ObjectId('67be3b4e52d92383db2b2220'), ObjectId('67be3b4e52d92383db2b2221'), ObjectId('67be3b4e52d92383db2b2222'), ObjectId('67be3b4e52d92383db2b2223'), ObjectId('67be3b4e52d92383db2b2224'), ObjectId('67be3b4e52d92383db2b2225'), ObjectId('67be3b4e52d92383db2b2226'), ObjectId('67be3b4e52d92383db2b2227'), ObjectId('67be3b4e52d92383db2b2228'), ObjectId('67be3b4e52d92383db2b2229'), ObjectId('67be3b4e52d92383db2b222a'), ObjectId('67be3b4e52d92383db2b222b'), ObjectId('67be3b4e52d92383db2b222c'), ObjectId('67be3b4e52d92383db2b222d'), ObjectId('67be3b4e52d92383db2b222e'), ObjectId('67be3b4e52d92383db2b222f'), ObjectId('67be3b4e52d92383db2b2230'), ObjectId('67be3b4e52d92383db2b2231'), ObjectId('67be3b4e52d92383db2b2232'), ObjectId('67be3b4e52d92383db2b2233'), ObjectId('67be3b4e52d92383db2b2234'), ObjectId('67be3b4e52d92383db2b2235'), ObjectId('67be3b4e52d92383db2b2236'), ObjectId('67be3b4e52d92383db2b2237'), ObjectId('67be3b4e52d92383db2b2238'), ObjectId('67be3b4e52d92383db2b2239'), ObjectId('67be3b4e52d92383db2b223a'), ObjectId('67be3b4e52d92383db2b223b'), ObjectId('67be3b4e52d92383db2b223c'), ObjectId('67be3b4e52d92383db2b223d'), ObjectId('67be3b4e52d92383db2b223e'), ObjectId('67be3b4e52d92383db2b223f'), ObjectId('67be3b4e52d92383db2b2240'), ObjectId('67be3b4e52d92383db2b2241'), ObjectId('67be3b4e52d92383db2b2242'), ObjectId('67be3b4e52d92383db2b2243'), ObjectId('67be3b4e52d92383db2b2244'), ObjectId('67be3b4e52d92383db2b2245'), ObjectId('67be3b4e52d92383db2b2246'), ObjectId('67be3b4e52d92383db2b2247'), ObjectId('67be3b4e52d92383db2b2248'), ObjectId('67be3b4e52d92383db2b2249'), ObjectId('67be3b4e52d92383db2b224a'), ObjectId('67be3b4e52d92383db2b224b'), ObjectId('67be3b4e52d92383db2b224c'), ObjectId('67be3b4e52d92383db2b224d'), ObjectId('67be3b4e52d92383db2b224e'), ObjectId('67be3b4e52d92383db2b224f'), ObjectId('67be3b4e52d92383db2b2250'), ObjectId('67be3b4e52d92383db2b2251'), ObjectId('67be3b4e52d92383db2b2252'), ObjectId('67be3b4e52d92383db2b2253'), ObjectId('67be3b4e52d92383db2b2254'), ObjectId('67be3b4e52d92383db2b2255'), ObjectId('67be3b4e52d92383db2b2256'), ObjectId('67be3b4e52d92383db2b2257'), ObjectId('67be3b4e52d92383db2b2258'), ObjectId('67be3b4e52d92383db2b2259'), ObjectId('67be3b4e52d92383db2b225a'), ObjectId('67be3b4e52d92383db2b225b'), ObjectId('67be3b4e52d92383db2b225c'), ObjectId('67be3b4e52d92383db2b225d'), ObjectId('67be3b4e52d92383db2b225e'), ObjectId('67be3b4e52d92383db2b225f'), ObjectId('67be3b4e52d92383db2b2260'), ObjectId('67be3b4e52d92383db2b2261'), ObjectId('67be3b4e52d92383db2b2262'), ObjectId('67be3b4e52d92383db2b2263'), ObjectId('67be3b4e52d92383db2b2264'), ObjectId('67be3b4e52d92383db2b2265'), ObjectId('67be3b4e52d92383db2b2266')], acknowledged=True)

# %% [markdown]
# ## Display all documents in the collection
#
# Display all documents in the collection using the `find` method. Use a `for` loop to iterate over the cursor returned by the `find` method and print each document. Use the `pprint` function from the `pprint` module to print the documents in a more readable format

# %%
from pprint import pprint

for doc in weather.find():
    pprint(doc)
# Out:
# {'_id': ObjectId('67be37f4e1bd313628714fd7'),
#  'date': '2024-02-26',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fd8'),
#  'date': '2024-02-27',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fd9'),
#  'date': '2024-02-28',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714fda'),
#  'date': '2024-02-29',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fdb'),
#  'date': '2024-03-01',
#  'humidity': 62,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714fdc'),
#  'date': '2024-03-02',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fdd'),
#  'date': '2024-03-03',
#  'humidity': 63,
#  'location': 'New York',
#  'temperature': 19,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714fde'),
#  'date': '2024-03-04',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fdf'),
#  'date': '2024-03-05',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fe0'),
#  'date': '2024-03-06',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714fe1'),
#  'date': '2024-02-26',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628714fe2'),
#  'date': '2024-02-27',
#  'humidity': 54,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628714fe3'),
#  'date': '2024-02-28',
#  'humidity': 56,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628714fe4'),
#  'date': '2024-02-29',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 27,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628714fe5'),
#  'date': '2024-03-01',
#  'humidity': 57,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714fe6'),
#  'date': '2024-03-02',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628714fe7'),
#  'date': '2024-03-03',
#  'humidity': 58,
#  'location': 'Los Angeles',
#  'temperature': 24,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714fe8'),
#  'date': '2024-03-04',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628714fe9'),
#  'date': '2024-03-05',
#  'humidity': 54,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628714fea'),
#  'date': '2024-03-06',
#  'humidity': 56,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628714feb'),
#  'date': '2024-02-26',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714fec'),
#  'date': '2024-02-27',
#  'humidity': 71,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714fed'),
#  'date': '2024-02-28',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fee'),
#  'date': '2024-02-29',
#  'humidity': 72,
#  'location': 'Chicago',
#  'temperature': 16,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714fef'),
#  'date': '2024-03-01',
#  'humidity': 73,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714ff0'),
#  'date': '2024-03-02',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714ff1'),
#  'date': '2024-03-03',
#  'humidity': 69,
#  'location': 'Chicago',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714ff2'),
#  'date': '2024-03-04',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714ff3'),
#  'date': '2024-03-05',
#  'humidity': 71,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714ff4'),
#  'date': '2024-03-06',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714ff5'),
#  'date': '2024-02-26',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714ff6'),
#  'date': '2024-02-27',
#  'humidity': 49,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714ff7'),
#  'date': '2024-02-28',
#  'humidity': 51,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628714ff8'),
#  'date': '2024-02-29',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 24,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714ff9'),
#  'date': '2024-03-01',
#  'humidity': 52,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714ffa'),
#  'date': '2024-03-02',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714ffb'),
#  'date': '2024-03-03',
#  'humidity': 53,
#  'location': 'Houston',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714ffc'),
#  'date': '2024-03-04',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628714ffd'),
#  'date': '2024-03-05',
#  'humidity': 49,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714ffe'),
#  'date': '2024-03-06',
#  'humidity': 51,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714fff'),
#  'date': '2024-02-26',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715000'),
#  'date': '2024-02-27',
#  'humidity': 44,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715001'),
#  'date': '2024-02-28',
#  'humidity': 46,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 9}
# {'_id': ObjectId('67be37f4e1bd313628715002'),
#  'date': '2024-02-29',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 25,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715003'),
#  'date': '2024-03-01',
#  'humidity': 47,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628715004'),
#  'date': '2024-03-02',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715005'),
#  'date': '2024-03-03',
#  'humidity': 48,
#  'location': 'Miami',
#  'temperature': 22,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715006'),
#  'date': '2024-03-04',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 9}
# {'_id': ObjectId('67be37f4e1bd313628715007'),
#  'date': '2024-03-05',
#  'humidity': 44,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715008'),
#  'date': '2024-03-06',
#  'humidity': 46,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715009'),
#  'date': '2024-02-26',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 3}
# {'_id': ObjectId('67be37f4e1bd31362871500a'),
#  'date': '2024-02-27',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be37f4e1bd31362871500b'),
#  'date': '2024-02-28',
#  'humidity': 66,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd31362871500c'),
#  'date': '2024-02-29',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 18,
#  'wind_speed': 3}
# {'_id': ObjectId('67be37f4e1bd31362871500d'),
#  'date': '2024-03-01',
#  'humidity': 67,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 2}
# {'_id': ObjectId('67be37f4e1bd31362871500e'),
#  'date': '2024-03-02',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be37f4e1bd31362871500f'),
#  'date': '2024-03-03',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 21,
#  'wind_speed': 3}
# {'_id': ObjectId('67be37f4e1bd313628715010'),
#  'date': '2024-03-04',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628715011'),
#  'date': '2024-03-05',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be37f4e1bd313628715012'),
#  'date': '2024-03-06',
#  'humidity': 66,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 3}
# {'_id': ObjectId('67be37f4e1bd313628715013'),
#  'date': '2024-02-26',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628715014'),
#  'date': '2024-02-27',
#  'humidity': 57,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628715015'),
#  'date': '2024-02-28',
#  'humidity': 59,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628715016'),
#  'date': '2024-02-29',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628715017'),
#  'date': '2024-03-01',
#  'humidity': 60,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628715018'),
#  'date': '2024-03-02',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628715019'),
#  'date': '2024-03-03',
#  'humidity': 61,
#  'location': 'Seattle',
#  'temperature': 20,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd31362871501a'),
#  'date': '2024-03-04',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd31362871501b'),
#  'date': '2024-03-05',
#  'humidity': 57,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd31362871501c'),
#  'date': '2024-03-06',
#  'humidity': 59,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd31362871501d'),
#  'date': '2024-02-26',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd31362871501e'),
#  'date': '2024-02-27',
#  'humidity': 51,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd31362871501f'),
#  'date': '2024-02-28',
#  'humidity': 53,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715020'),
#  'date': '2024-02-29',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 26,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628715021'),
#  'date': '2024-03-01',
#  'humidity': 54,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628715022'),
#  'date': '2024-03-02',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628715023'),
#  'date': '2024-03-03',
#  'humidity': 55,
#  'location': 'Dallas',
#  'temperature': 23,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628715024'),
#  'date': '2024-03-04',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be37f4e1bd313628715025'),
#  'date': '2024-03-05',
#  'humidity': 51,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628715026'),
#  'date': '2024-03-06',
#  'humidity': 53,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be37f4e1bd313628715031'),
#  'date': '2024-02-26',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628715032'),
#  'date': '2024-02-27',
#  'humidity': 61,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628715033'),
#  'date': '2024-02-28',
#  'humidity': 63,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628715034'),
#  'date': '2024-02-29',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628715035'),
#  'date': '2024-03-01',
#  'humidity': 64,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628715036'),
#  'date': '2024-03-02',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628715037'),
#  'date': '2024-03-03',
#  'humidity': 65,
#  'location': 'Phoenix',
#  'temperature': 19,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628715038'),
#  'date': '2024-03-04',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628715039'),
#  'date': '2024-03-05',
#  'humidity': 65,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd31362871503a'),
#  'date': '2024-03-06',
#  'humidity': 63,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715041'),
#  'date': '2024-02-26',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715042'),
#  'date': '2024-02-27',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715043'),
#  'date': '2024-02-28',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715044'),
#  'date': '2024-02-29',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715045'),
#  'date': '2024-03-01',
#  'humidity': 62,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd313628715046'),
#  'date': '2024-03-02',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715047'),
#  'date': '2024-03-03',
#  'humidity': 63,
#  'location': 'New York',
#  'temperature': 19,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715048'),
#  'date': '2024-03-04',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715049'),
#  'date': '2024-03-05',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd31362871504a'),
#  'date': '2024-03-06',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd31362871504b'),
#  'date': '2024-02-26',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd31362871504c'),
#  'date': '2024-02-27',
#  'humidity': 54,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd31362871504d'),
#  'date': '2024-02-28',
#  'humidity': 56,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd31362871504e'),
#  'date': '2024-02-29',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 27,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd31362871504f'),
#  'date': '2024-03-01',
#  'humidity': 57,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715050'),
#  'date': '2024-03-02',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715051'),
#  'date': '2024-03-03',
#  'humidity': 58,
#  'location': 'Los Angeles',
#  'temperature': 24,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715052'),
#  'date': '2024-03-04',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715053'),
#  'date': '2024-03-05',
#  'humidity': 54,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd313628715054'),
#  'date': '2024-03-06',
#  'humidity': 56,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715055'),
#  'date': '2024-02-26',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd313628715056'),
#  'date': '2024-02-27',
#  'humidity': 71,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd313628715057'),
#  'date': '2024-02-28',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715058'),
#  'date': '2024-02-29',
#  'humidity': 72,
#  'location': 'Chicago',
#  'temperature': 16,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd313628715059'),
#  'date': '2024-03-01',
#  'humidity': 73,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd31362871505a'),
#  'date': '2024-03-02',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd31362871505b'),
#  'date': '2024-03-03',
#  'humidity': 69,
#  'location': 'Chicago',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd31362871505c'),
#  'date': '2024-03-04',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd31362871505d'),
#  'date': '2024-03-05',
#  'humidity': 71,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd31362871505e'),
#  'date': '2024-03-06',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd31362871505f'),
#  'date': '2024-02-26',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715060'),
#  'date': '2024-02-27',
#  'humidity': 49,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715061'),
#  'date': '2024-02-28',
#  'humidity': 51,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715062'),
#  'date': '2024-02-29',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 24,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715063'),
#  'date': '2024-03-01',
#  'humidity': 52,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715064'),
#  'date': '2024-03-02',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715065'),
#  'date': '2024-03-03',
#  'humidity': 53,
#  'location': 'Houston',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715066'),
#  'date': '2024-03-04',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715067'),
#  'date': '2024-03-05',
#  'humidity': 49,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715068'),
#  'date': '2024-03-06',
#  'humidity': 51,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715069'),
#  'date': '2024-02-26',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd31362871506a'),
#  'date': '2024-02-27',
#  'humidity': 44,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd31362871506b'),
#  'date': '2024-02-28',
#  'humidity': 46,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 9}
# {'_id': ObjectId('67be3b40e1bd31362871506c'),
#  'date': '2024-02-29',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 25,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd31362871506d'),
#  'date': '2024-03-01',
#  'humidity': 47,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd31362871506e'),
#  'date': '2024-03-02',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd31362871506f'),
#  'date': '2024-03-03',
#  'humidity': 48,
#  'location': 'Miami',
#  'temperature': 22,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd313628715070'),
#  'date': '2024-03-04',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 9}
# {'_id': ObjectId('67be3b40e1bd313628715071'),
#  'date': '2024-03-05',
#  'humidity': 44,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd313628715072'),
#  'date': '2024-03-06',
#  'humidity': 46,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd313628715073'),
#  'date': '2024-02-26',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b40e1bd313628715074'),
#  'date': '2024-02-27',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b40e1bd313628715075'),
#  'date': '2024-02-28',
#  'humidity': 66,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd313628715076'),
#  'date': '2024-02-29',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 18,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b40e1bd313628715077'),
#  'date': '2024-03-01',
#  'humidity': 67,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 2}
# {'_id': ObjectId('67be3b40e1bd313628715078'),
#  'date': '2024-03-02',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b40e1bd313628715079'),
#  'date': '2024-03-03',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 21,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b40e1bd31362871507a'),
#  'date': '2024-03-04',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd31362871507b'),
#  'date': '2024-03-05',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b40e1bd31362871507c'),
#  'date': '2024-03-06',
#  'humidity': 66,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b40e1bd31362871507d'),
#  'date': '2024-02-26',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd31362871507e'),
#  'date': '2024-02-27',
#  'humidity': 57,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd31362871507f'),
#  'date': '2024-02-28',
#  'humidity': 59,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715080'),
#  'date': '2024-02-29',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715081'),
#  'date': '2024-03-01',
#  'humidity': 60,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715082'),
#  'date': '2024-03-02',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715083'),
#  'date': '2024-03-03',
#  'humidity': 61,
#  'location': 'Seattle',
#  'temperature': 20,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715084'),
#  'date': '2024-03-04',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715085'),
#  'date': '2024-03-05',
#  'humidity': 57,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715086'),
#  'date': '2024-03-06',
#  'humidity': 59,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715087'),
#  'date': '2024-02-26',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715088'),
#  'date': '2024-02-27',
#  'humidity': 51,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715089'),
#  'date': '2024-02-28',
#  'humidity': 53,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd31362871508a'),
#  'date': '2024-02-29',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 26,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd31362871508b'),
#  'date': '2024-03-01',
#  'humidity': 54,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd31362871508c'),
#  'date': '2024-03-02',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd31362871508d'),
#  'date': '2024-03-03',
#  'humidity': 55,
#  'location': 'Dallas',
#  'temperature': 23,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd31362871508e'),
#  'date': '2024-03-04',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b40e1bd31362871508f'),
#  'date': '2024-03-05',
#  'humidity': 51,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd313628715090'),
#  'date': '2024-03-06',
#  'humidity': 53,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b40e1bd31362871509b'),
#  'date': '2024-02-26',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd31362871509c'),
#  'date': '2024-02-27',
#  'humidity': 61,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd31362871509d'),
#  'date': '2024-02-28',
#  'humidity': 63,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd31362871509e'),
#  'date': '2024-02-29',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd31362871509f'),
#  'date': '2024-03-01',
#  'humidity': 64,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd3136287150a0'),
#  'date': '2024-03-02',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd3136287150a1'),
#  'date': '2024-03-03',
#  'humidity': 65,
#  'location': 'Phoenix',
#  'temperature': 19,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd3136287150a2'),
#  'date': '2024-03-04',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd3136287150a3'),
#  'date': '2024-03-05',
#  'humidity': 61,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd3136287150a4'),
#  'date': '2024-03-06',
#  'humidity': 63,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150ab'),
#  'date': '2024-02-26',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150ac'),
#  'date': '2024-02-27',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150ad'),
#  'date': '2024-02-28',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150ae'),
#  'date': '2024-02-29',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150af'),
#  'date': '2024-03-01',
#  'humidity': 62,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150b0'),
#  'date': '2024-03-02',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150b1'),
#  'date': '2024-03-03',
#  'humidity': 63,
#  'location': 'New York',
#  'temperature': 19,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150b2'),
#  'date': '2024-03-04',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150b3'),
#  'date': '2024-03-05',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150b4'),
#  'date': '2024-03-06',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150b5'),
#  'date': '2024-02-26',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150b6'),
#  'date': '2024-02-27',
#  'humidity': 54,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150b7'),
#  'date': '2024-02-28',
#  'humidity': 56,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150b8'),
#  'date': '2024-02-29',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 27,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150b9'),
#  'date': '2024-03-01',
#  'humidity': 57,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150ba'),
#  'date': '2024-03-02',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150bb'),
#  'date': '2024-03-03',
#  'humidity': 58,
#  'location': 'Los Angeles',
#  'temperature': 24,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150bc'),
#  'date': '2024-03-04',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150bd'),
#  'date': '2024-03-05',
#  'humidity': 54,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150be'),
#  'date': '2024-03-06',
#  'humidity': 56,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150bf'),
#  'date': '2024-02-26',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150c0'),
#  'date': '2024-02-27',
#  'humidity': 71,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150c1'),
#  'date': '2024-02-28',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150c2'),
#  'date': '2024-02-29',
#  'humidity': 72,
#  'location': 'Chicago',
#  'temperature': 16,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150c3'),
#  'date': '2024-03-01',
#  'humidity': 73,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150c4'),
#  'date': '2024-03-02',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150c5'),
#  'date': '2024-03-03',
#  'humidity': 69,
#  'location': 'Chicago',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150c6'),
#  'date': '2024-03-04',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150c7'),
#  'date': '2024-03-05',
#  'humidity': 71,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150c8'),
#  'date': '2024-03-06',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150c9'),
#  'date': '2024-02-26',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150ca'),
#  'date': '2024-02-27',
#  'humidity': 49,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150cb'),
#  'date': '2024-02-28',
#  'humidity': 51,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150cc'),
#  'date': '2024-02-29',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 24,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150cd'),
#  'date': '2024-03-01',
#  'humidity': 52,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150ce'),
#  'date': '2024-03-02',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150cf'),
#  'date': '2024-03-03',
#  'humidity': 53,
#  'location': 'Houston',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150d0'),
#  'date': '2024-03-04',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150d1'),
#  'date': '2024-03-05',
#  'humidity': 49,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150d2'),
#  'date': '2024-03-06',
#  'humidity': 51,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150d3'),
#  'date': '2024-02-26',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150d4'),
#  'date': '2024-02-27',
#  'humidity': 44,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150d5'),
#  'date': '2024-02-28',
#  'humidity': 46,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 9}
# {'_id': ObjectId('67be3b44e1bd3136287150d6'),
#  'date': '2024-02-29',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 25,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150d7'),
#  'date': '2024-03-01',
#  'humidity': 47,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150d8'),
#  'date': '2024-03-02',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150d9'),
#  'date': '2024-03-03',
#  'humidity': 48,
#  'location': 'Miami',
#  'temperature': 22,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150da'),
#  'date': '2024-03-04',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 9}
# {'_id': ObjectId('67be3b44e1bd3136287150db'),
#  'date': '2024-03-05',
#  'humidity': 44,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150dc'),
#  'date': '2024-03-06',
#  'humidity': 46,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150dd'),
#  'date': '2024-02-26',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b44e1bd3136287150de'),
#  'date': '2024-02-27',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b44e1bd3136287150df'),
#  'date': '2024-02-28',
#  'humidity': 66,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150e0'),
#  'date': '2024-02-29',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 18,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b44e1bd3136287150e1'),
#  'date': '2024-03-01',
#  'humidity': 67,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 2}
# {'_id': ObjectId('67be3b44e1bd3136287150e2'),
#  'date': '2024-03-02',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b44e1bd3136287150e3'),
#  'date': '2024-03-03',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 21,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b44e1bd3136287150e4'),
#  'date': '2024-03-04',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150e5'),
#  'date': '2024-03-05',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b44e1bd3136287150e6'),
#  'date': '2024-03-06',
#  'humidity': 66,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b44e1bd3136287150e7'),
#  'date': '2024-02-26',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150e8'),
#  'date': '2024-02-27',
#  'humidity': 57,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150e9'),
#  'date': '2024-02-28',
#  'humidity': 59,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150ea'),
#  'date': '2024-02-29',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150eb'),
#  'date': '2024-03-01',
#  'humidity': 60,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150ec'),
#  'date': '2024-03-02',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150ed'),
#  'date': '2024-03-03',
#  'humidity': 61,
#  'location': 'Seattle',
#  'temperature': 20,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150ee'),
#  'date': '2024-03-04',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150ef'),
#  'date': '2024-03-05',
#  'humidity': 57,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150f0'),
#  'date': '2024-03-06',
#  'humidity': 59,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150f1'),
#  'date': '2024-02-26',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150f2'),
#  'date': '2024-02-27',
#  'humidity': 51,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150f3'),
#  'date': '2024-02-28',
#  'humidity': 53,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150f4'),
#  'date': '2024-02-29',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 26,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150f5'),
#  'date': '2024-03-01',
#  'humidity': 54,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150f6'),
#  'date': '2024-03-02',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150f7'),
#  'date': '2024-03-03',
#  'humidity': 55,
#  'location': 'Dallas',
#  'temperature': 23,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150f8'),
#  'date': '2024-03-04',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b44e1bd3136287150f9'),
#  'date': '2024-03-05',
#  'humidity': 51,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd3136287150fa'),
#  'date': '2024-03-06',
#  'humidity': 53,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b44e1bd313628715105'),
#  'date': '2024-02-26',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd313628715106'),
#  'date': '2024-02-27',
#  'humidity': 61,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd313628715107'),
#  'date': '2024-02-28',
#  'humidity': 63,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd313628715108'),
#  'date': '2024-02-29',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd313628715109'),
#  'date': '2024-03-01',
#  'humidity': 64,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd31362871510a'),
#  'date': '2024-03-02',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd31362871510b'),
#  'date': '2024-03-03',
#  'humidity': 65,
#  'location': 'Phoenix',
#  'temperature': 19,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd31362871510c'),
#  'date': '2024-03-04',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd31362871510d'),
#  'date': '2024-03-05',
#  'humidity': 61,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd31362871510e'),
#  'date': '2024-03-06',
#  'humidity': 63,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2203'),
#  'date': '2024-02-26',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2204'),
#  'date': '2024-02-27',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2205'),
#  'date': '2024-02-28',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2206'),
#  'date': '2024-02-29',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2207'),
#  'date': '2024-03-01',
#  'humidity': 62,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2208'),
#  'date': '2024-03-02',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2209'),
#  'date': '2024-03-03',
#  'humidity': 63,
#  'location': 'New York',
#  'temperature': 19,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b220a'),
#  'date': '2024-03-04',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b220b'),
#  'date': '2024-03-05',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b220c'),
#  'date': '2024-03-06',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b220d'),
#  'date': '2024-02-26',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b220e'),
#  'date': '2024-02-27',
#  'humidity': 54,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b220f'),
#  'date': '2024-02-28',
#  'humidity': 56,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b2210'),
#  'date': '2024-02-29',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 27,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2211'),
#  'date': '2024-03-01',
#  'humidity': 57,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2212'),
#  'date': '2024-03-02',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2213'),
#  'date': '2024-03-03',
#  'humidity': 58,
#  'location': 'Los Angeles',
#  'temperature': 24,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2214'),
#  'date': '2024-03-04',
#  'humidity': 55,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2215'),
#  'date': '2024-03-05',
#  'humidity': 54,
#  'location': 'Los Angeles',
#  'temperature': 26,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b2216'),
#  'date': '2024-03-06',
#  'humidity': 56,
#  'location': 'Los Angeles',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2217'),
#  'date': '2024-02-26',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2218'),
#  'date': '2024-02-27',
#  'humidity': 71,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2219'),
#  'date': '2024-02-28',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b221a'),
#  'date': '2024-02-29',
#  'humidity': 72,
#  'location': 'Chicago',
#  'temperature': 16,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b221b'),
#  'date': '2024-03-01',
#  'humidity': 73,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b221c'),
#  'date': '2024-03-02',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b221d'),
#  'date': '2024-03-03',
#  'humidity': 69,
#  'location': 'Chicago',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b221e'),
#  'date': '2024-03-04',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b221f'),
#  'date': '2024-03-05',
#  'humidity': 71,
#  'location': 'Chicago',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2220'),
#  'date': '2024-03-06',
#  'humidity': 70,
#  'location': 'Chicago',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2221'),
#  'date': '2024-02-26',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2222'),
#  'date': '2024-02-27',
#  'humidity': 49,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2223'),
#  'date': '2024-02-28',
#  'humidity': 51,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2224'),
#  'date': '2024-02-29',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 24,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2225'),
#  'date': '2024-03-01',
#  'humidity': 52,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2226'),
#  'date': '2024-03-02',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2227'),
#  'date': '2024-03-03',
#  'humidity': 53,
#  'location': 'Houston',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2228'),
#  'date': '2024-03-04',
#  'humidity': 50,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2229'),
#  'date': '2024-03-05',
#  'humidity': 49,
#  'location': 'Houston',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b222a'),
#  'date': '2024-03-06',
#  'humidity': 51,
#  'location': 'Houston',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b222b'),
#  'date': '2024-02-26',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b222c'),
#  'date': '2024-02-27',
#  'humidity': 44,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b222d'),
#  'date': '2024-02-28',
#  'humidity': 46,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 9}
# {'_id': ObjectId('67be3b4e52d92383db2b222e'),
#  'date': '2024-02-29',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 25,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b222f'),
#  'date': '2024-03-01',
#  'humidity': 47,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2230'),
#  'date': '2024-03-02',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b2231'),
#  'date': '2024-03-03',
#  'humidity': 48,
#  'location': 'Miami',
#  'temperature': 22,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b2232'),
#  'date': '2024-03-04',
#  'humidity': 45,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 9}
# {'_id': ObjectId('67be3b4e52d92383db2b2233'),
#  'date': '2024-03-05',
#  'humidity': 44,
#  'location': 'Miami',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b2234'),
#  'date': '2024-03-06',
#  'humidity': 46,
#  'location': 'Miami',
#  'temperature': 23,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b2235'),
#  'date': '2024-02-26',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b4e52d92383db2b2236'),
#  'date': '2024-02-27',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b4e52d92383db2b2237'),
#  'date': '2024-02-28',
#  'humidity': 66,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2238'),
#  'date': '2024-02-29',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 18,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b4e52d92383db2b2239'),
#  'date': '2024-03-01',
#  'humidity': 67,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 2}
# {'_id': ObjectId('67be3b4e52d92383db2b223a'),
#  'date': '2024-03-02',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b4e52d92383db2b223b'),
#  'date': '2024-03-03',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 21,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b4e52d92383db2b223c'),
#  'date': '2024-03-04',
#  'humidity': 65,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b223d'),
#  'date': '2024-03-05',
#  'humidity': 64,
#  'location': 'San Francisco',
#  'temperature': 20,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b4e52d92383db2b223e'),
#  'date': '2024-03-06',
#  'humidity': 66,
#  'location': 'San Francisco',
#  'temperature': 19,
#  'wind_speed': 3}
# {'_id': ObjectId('67be3b4e52d92383db2b223f'),
#  'date': '2024-02-26',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2240'),
#  'date': '2024-02-27',
#  'humidity': 57,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2241'),
#  'date': '2024-02-28',
#  'humidity': 59,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2242'),
#  'date': '2024-02-29',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 23,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2243'),
#  'date': '2024-03-01',
#  'humidity': 60,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2244'),
#  'date': '2024-03-02',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2245'),
#  'date': '2024-03-03',
#  'humidity': 61,
#  'location': 'Seattle',
#  'temperature': 20,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2246'),
#  'date': '2024-03-04',
#  'humidity': 58,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2247'),
#  'date': '2024-03-05',
#  'humidity': 57,
#  'location': 'Seattle',
#  'temperature': 22,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2248'),
#  'date': '2024-03-06',
#  'humidity': 59,
#  'location': 'Seattle',
#  'temperature': 21,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2249'),
#  'date': '2024-02-26',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b224a'),
#  'date': '2024-02-27',
#  'humidity': 51,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b224b'),
#  'date': '2024-02-28',
#  'humidity': 53,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b224c'),
#  'date': '2024-02-29',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 26,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b224d'),
#  'date': '2024-03-01',
#  'humidity': 54,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b224e'),
#  'date': '2024-03-02',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b224f'),
#  'date': '2024-03-03',
#  'humidity': 55,
#  'location': 'Dallas',
#  'temperature': 23,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2250'),
#  'date': '2024-03-04',
#  'humidity': 52,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 8}
# {'_id': ObjectId('67be3b4e52d92383db2b2251'),
#  'date': '2024-03-05',
#  'humidity': 51,
#  'location': 'Dallas',
#  'temperature': 25,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2252'),
#  'date': '2024-03-06',
#  'humidity': 53,
#  'location': 'Dallas',
#  'temperature': 24,
#  'wind_speed': 7}
# {'_id': ObjectId('67be3b4e52d92383db2b2253'),
#  'date': '2024-02-26',
#  'humidity': 68,
#  'location': 'Boston',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2254'),
#  'date': '2024-02-27',
#  'humidity': 69,
#  'location': 'Boston',
#  'temperature': 16,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2255'),
#  'date': '2024-02-28',
#  'humidity': 68,
#  'location': 'Boston',
#  'temperature': 17,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2256'),
#  'date': '2024-02-29',
#  'humidity': 70,
#  'location': 'Boston',
#  'temperature': 15,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2257'),
#  'date': '2024-03-01',
#  'humidity': 71,
#  'location': 'Boston',
#  'temperature': 16,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2258'),
#  'date': '2024-03-02',
#  'humidity': 68,
#  'location': 'Boston',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2259'),
#  'date': '2024-03-03',
#  'humidity': 67,
#  'location': 'Boston',
#  'temperature': 18,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b225a'),
#  'date': '2024-03-04',
#  'humidity': 68,
#  'location': 'Boston',
#  'temperature': 17,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b225b'),
#  'date': '2024-03-05',
#  'humidity': 69,
#  'location': 'Boston',
#  'temperature': 16,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b225c'),
#  'date': '2024-03-06',
#  'humidity': 68,
#  'location': 'Boston',
#  'temperature': 17,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b225d'),
#  'date': '2024-02-26',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b225e'),
#  'date': '2024-02-27',
#  'humidity': 61,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b225f'),
#  'date': '2024-02-28',
#  'humidity': 63,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2260'),
#  'date': '2024-02-29',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2261'),
#  'date': '2024-03-01',
#  'humidity': 64,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2262'),
#  'date': '2024-03-02',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2263'),
#  'date': '2024-03-03',
#  'humidity': 65,
#  'location': 'Phoenix',
#  'temperature': 19,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2264'),
#  'date': '2024-03-04',
#  'humidity': 62,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2265'),
#  'date': '2024-03-05',
#  'humidity': 61,
#  'location': 'Phoenix',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2266'),
#  'date': '2024-03-06',
#  'humidity': 63,
#  'location': 'Phoenix',
#  'temperature': 20,
#  'wind_speed': 5}

# %% [markdown]
# ## Query documents for a specific location
# Find the documents for "New York" using the `find` method with a query filter. Make sure the documents are sorted by date in ascending order. Use a `for` loop to iterate over the cursor returned by the `find` method and print each document. Use the `pprint` function from the `pprint` module to print the documents in a more readable format.

# %%
query = {"location": "New York"}
sort = [("date", 1)]

for doc in weather.find(query).sort(sort):
    pprint(doc)
# Out:
# {'_id': ObjectId('67be37f4e1bd313628714fd7'),
#  'date': '2024-02-26',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715041'),
#  'date': '2024-02-26',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150ab'),
#  'date': '2024-02-26',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2203'),
#  'date': '2024-02-26',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fd8'),
#  'date': '2024-02-27',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715042'),
#  'date': '2024-02-27',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150ac'),
#  'date': '2024-02-27',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2204'),
#  'date': '2024-02-27',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fd9'),
#  'date': '2024-02-28',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715043'),
#  'date': '2024-02-28',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150ad'),
#  'date': '2024-02-28',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2205'),
#  'date': '2024-02-28',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714fda'),
#  'date': '2024-02-29',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715044'),
#  'date': '2024-02-29',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150ae'),
#  'date': '2024-02-29',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2206'),
#  'date': '2024-02-29',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 22,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fdb'),
#  'date': '2024-03-01',
#  'humidity': 62,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b40e1bd313628715045'),
#  'date': '2024-03-01',
#  'humidity': 62,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b44e1bd3136287150af'),
#  'date': '2024-03-01',
#  'humidity': 62,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be3b4e52d92383db2b2207'),
#  'date': '2024-03-01',
#  'humidity': 62,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 4}
# {'_id': ObjectId('67be37f4e1bd313628714fdc'),
#  'date': '2024-03-02',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715046'),
#  'date': '2024-03-02',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150b0'),
#  'date': '2024-03-02',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b2208'),
#  'date': '2024-03-02',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fdd'),
#  'date': '2024-03-03',
#  'humidity': 63,
#  'location': 'New York',
#  'temperature': 19,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd313628715047'),
#  'date': '2024-03-03',
#  'humidity': 63,
#  'location': 'New York',
#  'temperature': 19,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150b1'),
#  'date': '2024-03-03',
#  'humidity': 63,
#  'location': 'New York',
#  'temperature': 19,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b2209'),
#  'date': '2024-03-03',
#  'humidity': 63,
#  'location': 'New York',
#  'temperature': 19,
#  'wind_speed': 6}
# {'_id': ObjectId('67be37f4e1bd313628714fde'),
#  'date': '2024-03-04',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715048'),
#  'date': '2024-03-04',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150b2'),
#  'date': '2024-03-04',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b220a'),
#  'date': '2024-03-04',
#  'humidity': 60,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fdf'),
#  'date': '2024-03-05',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b40e1bd313628715049'),
#  'date': '2024-03-05',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b44e1bd3136287150b3'),
#  'date': '2024-03-05',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be3b4e52d92383db2b220b'),
#  'date': '2024-03-05',
#  'humidity': 59,
#  'location': 'New York',
#  'temperature': 21,
#  'wind_speed': 5}
# {'_id': ObjectId('67be37f4e1bd313628714fe0'),
#  'date': '2024-03-06',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b40e1bd31362871504a'),
#  'date': '2024-03-06',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b44e1bd3136287150b4'),
#  'date': '2024-03-06',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}
# {'_id': ObjectId('67be3b4e52d92383db2b220c'),
#  'date': '2024-03-06',
#  'humidity': 61,
#  'location': 'New York',
#  'temperature': 20,
#  'wind_speed': 6}

# %% [markdown]
# ## Update the  documents relative to "Phoenix"
#
# The humidity sensor relative to "Phoenix" on the "2024-03-05" was found to be faulty and the humidity value should be 65. Update the document using the `update_one` method and update the document in place. You can use the `set` operator to update the field.

# %%
query = {"location": "Phoenix", "date": "2024-03-05"}
update = {"$set": {"humidity": 65}}

update_result = weather.update_one(query, update)
update_result.modified_count
# Out:
# 0

# %% [markdown]
# ## Find the maximum temperature
#
# Find the maximum temperature between all documents in the collection.

# %%
weather.find_one(sort=[("temperature", -1)])
# Out:
# {'_id': ObjectId('67be37f4e1bd313628714fe4'),
#  'date': '2024-02-29',
#  'temperature': 27,
#  'humidity': 55,
#  'wind_speed': 7,
#  'location': 'Los Angeles'}

# %% [markdown]
# ## Find the minimum humidity
#
# Find the minimum humidity between all documents in the collection.

# %%
weather.find_one(sort=[("humidity", 1)])
# Out:
# {'_id': ObjectId('67be37f4e1bd313628715000'),
#  'date': '2024-02-27',
#  'temperature': 24,
#  'humidity': 44,
#  'wind_speed': 8,
#  'location': 'Miami'}

# %% [markdown]
# ## Find the average temperature
# find the average temperature using the aggregate function. See the aggregate function in the [https://www.mongodb.com/docs/manual/reference/operator/aggregation/](https://www.mongodb.com/docs/manual/reference/operator/aggregation/)

# %%
list(weather.aggregate(
    [
        {
            "$group": {
                "_id": None,
                "avg_temp": {"$avg": "$temperature"}
            }
        }
    ]
))
# Out:
# [{'_id': None, 'avg_temp': 21.508108108108107}]

# %% [markdown]
# Find the average temperature for each location

# %%
list(weather.aggregate(
    [
        {
            "$group": {
                "_id": "$location",
                "avg_temp": {"$avg": "$temperature"}
            }
        }
    ]
))
# Out:
# [{'_id': 'Boston', 'avg_temp': 16.6},
#  {'_id': 'New York', 'avg_temp': 20.4},
#  {'_id': 'Miami', 'avg_temp': 23.4},
#  {'_id': 'Houston', 'avg_temp': 22.4},
#  {'_id': 'Chicago', 'avg_temp': 17.6},
#  {'_id': 'Dallas', 'avg_temp': 24.4},
#  {'_id': 'Phoenix', 'avg_temp': 20.4},
#  {'_id': 'Seattle', 'avg_temp': 21.4},
#  {'_id': 'San Francisco', 'avg_temp': 19.4},
#  {'_id': 'Los Angeles', 'avg_temp': 25.4}]

# %% [markdown]
# ## Delete the documents relative to "Boston"
#
# Check that the documents wer deleted using, e.g., the delete_count attribute of the result object.

# %%
weather.delete_many({"location": "Boston"})
# Out:
# DeleteResult({'n': 10, 'ok': 1.0}, acknowledged=True)

# %% [markdown]
# # An embeded document case
#
# Consider the following data

# %%
import pymongo

# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client.weatherdb
weather2 = db.weather2

# Sample data - list of documents with weather information for multiple dates and locations
weather_data = [
    {"location": "New York", "dates": [
        {"date": "2024-02-26", "temperature": 20, "humidity": 60, "wind_speed": 5},
        {"date": "2024-02-27", "temperature": 22, "humidity": 65, "wind_speed": 6},
        {"date": "2024-02-28", "temperature": 18, "humidity": 55, "wind_speed": 4}
    ]},
    {"location": "Los Angeles", "dates": [
        {"date": "2024-02-26", "temperature": 25, "humidity": 55, "wind_speed": 7},
        {"date": "2024-02-27", "temperature": 27, "humidity": 50, "wind_speed": 6},
        {"date": "2024-02-28", "temperature": 24, "humidity": 58, "wind_speed": 5}
    ]},
    {"location": "Chicago", "dates": [
        {"date": "2024-02-26", "temperature": 18, "humidity": 70, "wind_speed": 4},
        {"date": "2024-02-27", "temperature": 20, "humidity": 68, "wind_speed": 3},
        {"date": "2024-02-28", "temperature": 16, "humidity": 72, "wind_speed": 5}
    ]},
    {"location": "Houston", "dates": [
        {"date": "2024-02-26", "temperature": 22, "humidity": 50, "wind_speed": 6},
        {"date": "2024-02-27", "temperature": 24, "humidity": 48, "wind_speed": 7},
        {"date": "2024-02-28", "temperature": 21, "humidity": 52, "wind_speed": 5}
    ]},
    # Add more locations with multiple dates and weather data
]

weather2.insert_many(weather_data)
# Out:
# InsertManyResult([ObjectId('67be3b4e52d92383db2b2268'), ObjectId('67be3b4e52d92383db2b2269'), ObjectId('67be3b4e52d92383db2b226a'), ObjectId('67be3b4e52d92383db2b226b')], acknowledged=True)

# %% [markdown]
# ## Find the average humidity for each location
#
# See the aggregate function  and the project operator. This operator allows you to specify which fields you want to return.
#
# Suggestion:  see the `unwind` operator which is used to deconstruct an array field from the input documents to output a document for each element of the array. Each output document is a version of the input document with the value of the array field replaced by the element. This stage is particularly useful for working with documents that contain an array of subdocuments or values, allowing you to perform operations on each element of the array as if it were part of a separate document.

# %%
list(
    weather2.aggregate([
        {"$unwind": "$dates"},
        {
            "$group": {
                "_id": "$location",
                "avg_humidity": {"$avg": "$dates.humidity"}
            }
        }
    ])
)
# Out:
# [{'_id': 'Los Angeles', 'avg_humidity': 54.333333333333336},
#  {'_id': 'Houston', 'avg_humidity': 50.0},
#  {'_id': 'Chicago', 'avg_humidity': 70.0},
#  {'_id': 'New York', 'avg_humidity': 60.0}]

# %% [markdown]
# ## Find the mean humidity for each date

# %%
list(
    weather2.aggregate([
        {"$unwind": "$dates"},
        {
            "$group": {
                "_id": "$dates.date",
                "mean_humidity": {"$avg": "$dates.humidity"},
                "max_humidity": {"$max": "$dates.humidity"},
                "min_humidity": {"$min": "$dates.humidity"}
            }
        }
    ])
)
# Out:
# [{'_id': '2024-02-27',
#   'mean_humidity': 57.75,
#   'max_humidity': 68,
#   'min_humidity': 48},
#  {'_id': '2024-02-26',
#   'mean_humidity': 58.75,
#   'max_humidity': 70,
#   'min_humidity': 50},
#  {'_id': '2024-02-28',
#   'mean_humidity': 59.25,
#   'max_humidity': 72,
#   'min_humidity': 52}]

# %% [markdown]
# ## Find the maximum temperature for each location

# %%
list(weather2.aggregate([
    {"$unwind": "$dates"},
    {
        "$group": {
            "_id": "$location",
            "max_temp": {"$max": "$dates.temperature"}
        }
    }
])
)
# Out:
# [{'_id': 'Los Angeles', 'max_temp': 27},
#  {'_id': 'Houston', 'max_temp': 24},
#  {'_id': 'Chicago', 'max_temp': 20},
#  {'_id': 'New York', 'max_temp': 22}]
